# %%
import pandas as pd
import requests
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt1
import numpy as np
import matplotlib.ticker as ticker
from numpy.random import randint
import math as Math
import matplotlib.dates as mdates
from datetime import datetime
from dateutil.relativedelta import relativedelta

# %%
data_atual = datetime.now()-relativedelta(months=1)
data_atual = data_atual.strftime('%Y-%m-%d')
data_atual_replace = data_atual.replace(str(data_atual[-2:]),'01')


df = pd.read_csv("https://olinda.bcb.gov.br/olinda/servico/taxaJuros/versao/v2/odata/TaxasJurosMensalPorMes?$top=1000&$format=text/csv&$select=Mes,Modalidade,InstituicaoFinanceira,TaxaJurosAoMes,TaxaJurosAoAno,anoMes")
df = df.sort_values(by = ['TaxaJurosAoMes','anoMes'], ascending=False)
df['anoMes'] = pd.to_datetime(df['anoMes'])
print(data_atual_replace)
df1 = df['Modalidade'].str.contains(r'FINANCIAMENTO IMOBILIÁRIO(?!$)')
mask0 =df['TaxaJurosAoMes'].str.contains(r'(?:\s|^)0(?:\s|$)') == False
mask = (df['anoMes'] >= '2022-04-01') & (df['anoMes'] <= data_atual)
df = df.loc[mask & df1 & mask0] 
df
# Out:
# 2022-04-01
#          Mes                                         Modalidade  \
# 22  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 20  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 14  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 12  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 9   Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 4   Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...
# 5   Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 2   Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...
# 36  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 38  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 39  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...
# 1   Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS DE MERCADO...
# 37  Abr-2022  FINANCIAMENTO IMOBILIÁRIO COM TAXAS REGULADAS ...
# ...
